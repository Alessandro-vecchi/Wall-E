# %%
import pandas as pd

df = pd.read_csv('log_4.csv')
df
# Out:
#     RoadCenter  Distance  Motors Power  Curve Average  Curve M2  Steering
# 0          261        21         0.097            296      0.35       0.5
# 1          261        21         0.097            296      0.35       0.5
# 2          261        21         0.097            296      0.35       0.5
# 3          261        21         0.097            296      0.35       0.5
# 4          261        21         0.097            296      0.35       0.5
# 5          261        21         0.097            296      0.35       0.5
# 6          261        21         0.097            296      0.35       0.5
# 7          260        20         0.095            295      0.35       0.5
# 8          259        19         0.092            294      0.35       0.5
# 9          258        18         0.090            292      0.34       0.5
# 10         257        17         0.087            290      0.34       0.5
# 11         256        16         0.085            289      0.34       0.5
# ...
